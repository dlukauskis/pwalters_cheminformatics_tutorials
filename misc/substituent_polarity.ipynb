# %% [markdown]
# ## Substituent Polarity

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem.rdMMPA import FragmentMol
from operator import itemgetter
import useful_rdkit_utils as uru
import mols2grid
from tqdm.auto import tqdm

# %%
# import requests
# lib_file = requests.get("https://raw.githubusercontent.com/PatWalters/practical_cheminformatics_tutorials/main/sar_analysis/scaffold_finder.py")
# ofs = open("scaffold_finder.py","w")
# print(lib_file.text,file=ofs)
# ofs.close()
import sys
sys.path.append('/home/dom/Projects/Playground/practical_cheminformatics_tutorials/sar_analysis')
from scaffold_finder import generate_fragments, cleanup_fragment

# %% [markdown]
# Useful utility functions

# %%
def remove_map_nums(mol):
    for atm in mol.GetAtoms():
        atm.SetAtomMapNum(0)

def sort_fragments(mol):
    """
    Transform a molecule with multiple fragments into a list of molecules that is sorted by number of atoms
    from largest to smallest
    """
    frag_list = list(Chem.GetMolFrags(mol, asMols=True))
    [remove_map_nums(x) for x in frag_list]
    frag_num_atoms_list = [(x.GetNumAtoms(), x) for x in frag_list]
    frag_num_atoms_list.sort(key=itemgetter(0), reverse=True)
    return [x[1] for x in frag_num_atoms_list]

def smi2logp(smi):
    mol = Chem.MolFromSmiles(smi)
    return uru.MolLogP(mol)

# %% [markdown]
# ### Read Input
# Read the input data

# %%
infile_url = "https://raw.githubusercontent.com/PatWalters/datafiles/main/chembl_drugs.smi"
drug_df = pd.read_csv(infile_url,sep=" ",names=["SMILES","Name"])

# %% [markdown]
# Add an RDKit molecule to the dataframe

# %%
drug_df['mol'] = drug_df.SMILES.apply(Chem.MolFromSmiles)
drug_df.mol = drug_df.mol.apply(uru.get_largest_fragment)

# %% [markdown]
# ### Generate Scaffold-Substituent Pairs
# Iterate over the molecules in the dataframe and transform to scaffold, substituent pairs

# %%
row_list = []
for smiles, name, mol in tqdm(drug_df.values):
    frag_list = FragmentMol(mol,maxCuts=1)
    for _,frag_mol in frag_list:
        pair_list = sort_fragments(frag_mol)
        row_list.append([smiles]+[Chem.MolToSmiles(x) for x in pair_list]+[name])
row_df = pd.DataFrame(row_list,columns=["SMILES","Core","R_group","Name"])
row_df
# Out:
#   0%|          | 0/1203 [00:00<?, ?it/s]
#                                                  SMILES  \
# 0                         Nc1ccc(S(=O)(=O)Nc2ccccn2)cc1
# 1                         Nc1ccc(S(=O)(=O)Nc2ccccn2)cc1
# 2                         Nc1ccc(S(=O)(=O)Nc2ccccn2)cc1
# 3                 CCC(C)C1(CC)C(=O)[N-]C(=O)NC1=O.[Na+]
# 4                 CCC(C)C1(CC)C(=O)[N-]C(=O)NC1=O.[Na+]
# ...                                                 ...
# 8104  CONC(=O)Nc1ccc(-c2sc3c(c2CN(C)C)c(=O)n(-c2ccc(...
# 8105  CONC(=O)Nc1ccc(-c2sc3c(c2CN(C)C)c(=O)n(-c2ccc(...
# 8106  CONC(=O)Nc1ccc(-c2sc3c(c2CN(C)C)c(=O)n(-c2ccc(...
# 8107  CONC(=O)Nc1ccc(-c2sc3c(c2CN(C)C)c(=O)n(-c2ccc(...
# 8108  CONC(=O)Nc1ccc(-c2sc3c(c2CN(C)C)c(=O)n(-c2ccc(...
#
#                                                    Core         R_group  \
# 0                         *c1ccc(S(=O)(=O)Nc2ccccn2)cc1              *N
# 1                                   *S(=O)(=O)Nc1ccccn1    *c1ccc(N)cc1
# 2                                *NS(=O)(=O)c1ccc(N)cc1       *c1ccccn1
# 3                       *CC(C)C1(CC)C(=O)[N-]C(=O)NC1=O              *C
# 4                        *C(C)C1(CC)C(=O)[N-]C(=O)NC1=O             *CC
# ...                                                 ...             ...
# 8104  *c1ccc(-n2c(=O)c3c(CN(C)C)c(-c4ccc(NC(=O)NOC)c...             *OC
# 8105  *Oc1ccc(-n2c(=O)c3c(CN(C)C)c(-c4ccc(NC(=O)NOC)...              *C
# 8106  *n1c(=O)n(-c2ccc(OC)nn2)c(=O)c2c(CN(C)C)c(-c3c...  *Cc1c(F)cccc1F
# 8107  *Cn1c(=O)n(-c2ccc(OC)nn2)c(=O)c2c(CN(C)C)c(-c3...   *c1c(F)cccc1F
# 8108  *c1cccc(F)c1Cn1c(=O)n(-c2ccc(OC)nn2)c(=O)c2c(C...              *F
#
#                Name
# 0         CHEMBL700
# 1         CHEMBL700
# 2         CHEMBL700
# 3     CHEMBL1200982
# 4     CHEMBL1200982
# ...             ...
# 8104  CHEMBL1800159
# 8105  CHEMBL1800159
# 8106  CHEMBL1800159
# 8107  CHEMBL1800159
# 8108  CHEMBL1800159
#
# [8109 rows x 4 columns]

# %% [markdown]
# Create a dataframe with substituents and number of occurrences. Change **min_occurrences** below to a smaller value to increase the number of substituents shown.

# %%
min_occurrences = 20
substituent_df = row_df.R_group.value_counts().to_frame().reset_index()
substituent_df.columns = ["SMILES","Count"]
substituent_df['LogP'] = substituent_df.SMILES.apply(smi2logp)
frequent_substituent_df = substituent_df.query("Count >= @min_occurrences").sort_values("LogP")

# %% [markdown]
# Display the substituents in a grid.

# %%
mols2grid.display(frequent_substituent_df,
                 subset=["img","LogP","Count"],
                 transform={
                 "LogP": lambda x: f"{x:.2f}"},
                 selection=False,
                 custom_css=""".data-mols2grid-id-display { display: none }""")
# Out:
# <iframe class="mols2grid-iframe" width=100% height="586" frameborder="0" srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#       #mols2grid.gridcontainer {
#         display: block;
#         padding-left: 1em;
#         max-width: 820px;
#         width: 820px;
#       }
#       #mols2grid .cell {
#         border: 1px solid #cccccc;
#         text-align: center;
#         vertical-align: top;
#         max-width: 160px;
#         width: 160px;
#         font-family: &#x27;DejaVu&#x27;, sans-serif;
#         font-size: 12pt;
#         padding: 0;
#         margin: 0;
#         float: left;
#       }
#       #mols2grid .cell:hover {
#         background-color: #e7e7e7;
#       }
#       #mols2grid .cell img, #mols2grid .cell svg {
#         max-width: 100%;
#         height: auto;
#         padding: 0;
#       }
#       #mols2grid .data {
#         overflow: hidden;
#         white-space: nowrap;
#         text-overflow: ellipsis;
#         display: block;
#       }
#       #mols2grid .arrow-asc:after {
#         content: &#x27;↑&#x27;;
#         text-align: right;
#         float:right;
#       }
#       #mols2grid .arrow-desc:after {
#         content: &#x27;↓&#x27;;
#         text-align: right;
#         float:right;
#       }
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/list.js/2.3.1/list.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/css/bootstrap.min.css&quot; integrity=&quot;sha384-B0vP5xmATw1+K9KRQjQERJvTumQW0nPEzvF6L/Z6nronJ3oUOFUFpCjEUQouq2+l&quot; crossorigin=&quot;anonymous&quot;&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.5.1.slim.min.js&quot; integrity=&quot;sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@rdkit/rdkit@2021.3.2/Code/MinimalLib/dist/RDKit_minimal.js&quot;&gt;&lt;/script&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mols2grid&quot; class=&quot;gridcontainer&quot;&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;div class=&quot;list&quot;&gt;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-LogP&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Count&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-SMILES&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#       &lt;/div&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;ul class=&quot;pagination pt-3 pl-3 col&quot;&gt;&lt;/ul&gt;
#         &lt;div class=&quot;dropdown float-right col-1 py-3 mr-4&quot;&gt;
#           &lt;button class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; id=&quot;sortDropdown&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;
#             Sort by
#           &lt;/button&gt;
#           &lt;div class=&quot;dropdown-menu&quot; aria-labelledby=&quot;sortDropdownMenu&quot;&gt;
#
#
#             &lt;button class=&quot;dropdown-item sort-btn arrow-asc active&quot; type=&quot;button&quot; data-name=&quot;mols2grid-id&quot;&gt;Index&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-LogP&quot;&gt;Logp&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-Count&quot;&gt;Count&lt;/button&gt;
#
#
#           &lt;/div&gt;
#         &lt;/div&gt;
#         &lt;div class=&quot;input-group float-right col-4 py-3 mr-3 ml-2&quot;&gt;
#           &lt;input type=&quot;text&quot; id=&quot;searchbar&quot; class=&quot;form-control&quot; placeholder=&quot;Search&quot; aria-label=&quot;Search&quot; aria-describedby=&quot;basic-addon1&quot;&gt;
#           &lt;div class=&quot;input-group-append&quot;&gt;
#             &lt;button id=&quot;searchBtn&quot; class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;🔎&lt;/button&gt;
#             &lt;div class=&quot;dropdown-menu dropdown-menu-right&quot;&gt;
#               &lt;button id=&quot;txtSearch&quot; class=&quot;search-btn dropdown-item active&quot;&gt;Text&lt;/button&gt;
#               &lt;button id=&quot;smartsSearch&quot; class=&quot;search-btn dropdown-item&quot;&gt;SMARTS&lt;/button&gt;
#             &lt;/div&gt;
#           &lt;/div&gt;
#         &lt;/div&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#     &lt;script&gt;
#       // RDKit
#       onRuntimeInitialized: initRDKitModule().then(function(instance) {
#         RDKitModule = instance;
#         console.log(&#x27;RDKit version: &#x27; + RDKitModule.version());
#       });
#       // pages
#       var listObj = new List(&#x27;mols2grid&#x27;,
#         {
#           valueNames: [{data: [&#x27;mols2grid-id&#x27;]}, &#x27;data-SMILES&#x27;, &#x27;data-Count&#x27;, &#x27;data-img&#x27;, &#x27;data-LogP&#x27;],
#           item: &#x27;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-LogP&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Count&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-SMILES&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&#x27;,
#           page: 15,
#           pagination: {
#             name: &quot;pagination&quot;,
#             item: &#x27;&lt;li class=&quot;page-item&quot;&gt;&lt;a class=&quot;page page-link&quot; href=&quot;#&quot; onclick=&quot;event.preventDefault()&quot;&gt;&lt;/a&gt;&lt;/li&gt;&#x27;,
#             innerWindow: 1,
#             outerWindow: 1,
#           },
#         }
#       );
#       listObj.remove(&quot;mols2grid-id&quot;, &quot;0&quot;)
#       listObj.add([{&quot;data-LogP&quot;: &quot;-1.30&quot;, &quot;data-SMILES&quot;: &quot;*CC(=O)[O-]&quot;, &quot;data-Count&quot;: 26, &quot;data-img&quot;: &quot;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;iso-8859-1&#x27;?&gt;\n&lt;svg version=&#x27;1.1&#x27; baseProfile=&#x27;full&#x27;\n              xmlns=&#x27;http://www.w3.org/2000/svg&#x27;\n                      xmlns:rdkit=&#x27;http://www.rdkit.org/xml&#x27;\n                      xmlns:xlink=&#x27;http://www.w3.org/1999/xlink&#x27;\n                  xml:space=&#x27;preserve&#x27;\nwidth=&#x27;160px&#x27; height=&#x27;120px&#x27; viewBox=&#x27;0 0 160 120&#x27;&gt;\n&lt;!-- END OF HEADER --&gt;\n&lt;rect style=&#x27;opacity:1.0;fill:#FFFFFF;stroke:none&#x27; width=&#x27;160.0&#x27; height=&#x27;120.0&#x27; x=&#x27;0.0&#x27; y=&#x27;0.0&#x27;&gt; &lt;/rect&gt;\n&lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 113.9,13.9 L 113.9,32.2&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#191919;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 113.9,32.2 L 113.9,50.6&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 113.9,50.6 L 81.8,69.2&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-2 atom-2 atom-3&#x27; d=&#x27;M 84.6,67.6 L 72.1,60.4&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path cla
