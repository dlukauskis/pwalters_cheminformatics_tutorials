# %% [markdown]
# ## Identifying Scaffolds in a Set of Molecules
#
# ### Introduction
# In Cheminformatics, we frequently run into cases where we want to understand structure-activity relationships in a set of molecules.  In order to do this, we typically separate the molecules based on common scaffolds, then create an R-group table to explore the substituents that have been attached to the scaffold.  In addition, identifying scaffolds allows us to perform tasks like aligning molecules that will enable us to more easily compare the molecules.  In this notebook we'll use a method inspired by a 2019 paper by [Naveja, Vogt, Stumpfe, Medina-Franco, and Bajorath](https://pubs.acs.org/doi/full/10.1021/acsomega.8b03390). The method operates by carrying out three steps.
#
# 1. Decompose each molecule into a set of fragments.  In this case we'll use the [FragmentMol](https://www.rdkit.org/docs/source/rdkit.Chem.rdMMPA.html) function from the Matched Molecular Pair Analysis (MMPA) functions in the RDKit decompose a molecule into a set of fragments.  The RDKit MMPA methods use the [Hussain and Rea](https://pubs.acs.org/doi/10.1021/ci900450m) methodology, which fragments a molecule by successively disconnecting acyclic single bonds.
# 2. Remove any fragments where the number of atoms is less than 2/3 the number of atoms in the original molecule.
# 3. Collect fragments and records their frequency. We can do this easily using the Pandas [groupby](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html) method.
#
# All of these functions have been encapsulated in a small python library called scaffold_finder.  In this notebook, we'll use four functions from this library.
# * generate_fragments - performs steps 1 and 2 above.
# * find scaffolds - performs step 3 above
# * cleanup_fragments - takes a set of fragments generated by steps 1 and 2 above, and coverts them to scaffolds
# * get_molecules_with_scaffold - select molecules containing a specified fragment from a Pandas dataframe.

# %% [markdown]
# In order to run on Google Colab, you'll need to execute the cell below to install the rdkit, Pandas, and mols2grid.

# %%
# !pip install pandas requests mols2grid useful-rdkit-utils
# Out:
# Requirement already satisfied: pandas in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (1.4.3)
# Requirement already satisfied: requests in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (2.28.0)
# Requirement already satisfied: mols2grid in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (0.2.4)
# Requirement already satisfied: useful-rdkit-utils in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (0.1.6)
# Requirement already satisfied: pytz>=2020.1 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from pandas) (1.22.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from requests) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from requests) (2022.5.18.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from requests) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from requests) (2.0.12)
# Requirement already satisfied: jinja2>=2.11.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from mols2grid) (3.1.2)
# Requirement already satisfied: Pillow in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from useful-rdkit-utils) (9.1.1)
# Requirement already satisfied: jupyter in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from useful-rdkit-utils) (1.0.0)
# Requirement already satisfied: rdkit-pypi in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from useful-rdkit-utils) (2022.3.3)
# Requirement already satisfied: pystow in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from useful-rdkit-utils) (0.4.4)
# Requirement already satisfied: py3DMol in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from useful-rdkit-utils) (1.8.0)
# Requirement already satisfied: pytest in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from useful-rdkit-utils) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from jinja2>=2.11.0->mols2grid) (2.1.1)
# Requirement already satisfied: six>=1.5 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: notebook in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from jupyter->useful-rdkit-utils) (6.4.12)
# Requirement already satisfied: nbconvert in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from jupyter->useful-rdkit-utils) (6.5.0)
# Requirement already satisfied: ipywidgets in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from jupyter->useful-rdkit-utils) (7.7.0)
# Requirement already satisfied: qtconsole in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from jupyter->useful-rdkit-utils) (5.3.1)
# Requirement already satisfied: jupyter-console in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from jupyter->useful-rdkit-utils) (6.4.3)
# Requirement already satisfied: ipykernel in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from jupyter->useful-rdkit-utils) (6.15.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipykernel->jupyter->useful-rdkit-utils) (7.3.4)
# Requirement already satisfied: traitlets>=5.1.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipykernel->jupyter->useful-rdkit-utils) (5.3.0)
# Requirement already satisfied: nest-asyncio in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipykernel->jupyter->useful-rdkit-utils) (1.5.5)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipykernel->jupyter->useful-rdkit-utils) (0.1.3)
# Requirement already satisfied: ipython>=7.23.1 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipykernel->jupyter->useful-rdkit-utils) (8.4.0)
# Requirement already satisfied: psutil in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipykernel->jupyter->useful-rdkit-utils) (5.9.1)
# Requirement already satisfied: tornado>=6.1 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipykernel->jupyter->useful-rdkit-utils) (6.1)
# Requirement already satisfied: appnope in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipykernel->jupyter->useful-rdkit-utils) (0.1.3)
# Requirement already satisfied: debugpy>=1.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipykernel->jupyter->useful-rdkit-utils) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipykernel->jupyter->useful-rdkit-utils) (23.1.0)
# Requirement already satisfied: packaging in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipykernel->jupyter->useful-rdkit-utils) (21.3)
# Requirement already satisfied: decorator in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->useful-rdkit-utils) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->useful-rdkit-utils) (2.12.0)
# Requirement already satisfied: backcall in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->useful-rdkit-utils) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->useful-rdkit-utils) (61.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->useful-rdkit-utils) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->useful-rdkit-utils) (0.7.5)
# Requirement already satisfied: stack-data in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->useful-rdkit-utils) (0.3.0)
# Requirement already satisfied: jedi>=0.16 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->useful-rdkit-utils) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter->useful-rdkit-utils) (3.0.29)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->useful-rdkit-utils) (0.8.3)
# Requirement already satisfied: entrypoints in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->useful-rdkit-utils) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->useful-rdkit-utils) (4.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->useful-rdkit-utils) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->jupyter->useful-rdkit-utils) (0.2.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipywidgets->jupyter->useful-rdkit-utils) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipywidgets->jupyter->useful-rdkit-utils) (5.4.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipywidgets->jupyter->useful-rdkit-utils) (1.1.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from ipywidgets->jupyter->useful-rdkit-utils) (3.6.0)
# Requirement already satisfied: fastjsonschema in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->useful-rdkit-utils) (2.15.3)
# Requirement already satisfied: jsonschema>=2.6 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->useful-rdkit-utils) (4.6.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->useful-rdkit-utils) (5.8.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->useful-rdkit-utils) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->useful-rdkit-utils) (0.18.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->useful-rdkit-utils) (3.8.0)
# Requirement already satisfied: prometheus-client in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from notebook->jupyter->useful-rdkit-utils) (0.14.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from notebook->jupyter->useful-rdkit-utils) (1.8.0)
# Requirement already satisfied: argon2-cffi in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from notebook->jupyter->useful-rdkit-utils) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from notebook->jupyter->useful-rdkit-utils) (0.15.0)
# Requirement already satisfied: beautifulsoup4 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from nbconvert->jupyter->useful-rdkit-utils) (4.11.1)
# Requirement already satisfied: tinycss2 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from nbconvert->jupyter->useful-rdkit-utils) (1.1.1)
# Requirement already satisfied: bleach in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from nbconvert->jupyter->useful-rdkit-utils) (5.0.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from nbconvert->jupyter->useful-rdkit-utils) (0.6.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from nbconvert->jupyter->useful-rdkit-utils) (0.2.2)
# Requirement already satisfied: defusedxml in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from nbconvert->jupyter->useful-rdkit-utils) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from nbconvert->jupyter->useful-rdkit-utils) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from nbconvert->jupyter->useful-rdkit-utils) (0.8.4)
# Requirement already satisfied: argon2-cffi-bindings in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from argon2-cffi->notebook->jupyter->useful-rdkit-utils) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->useful-rdkit-utils) (1.15.0)
# Requirement already satisfied: pycparser in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->useful-rdkit-utils) (2.21)
# Requirement already satisfied: soupsieve>1.2 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from beautifulsoup4->nbconvert->jupyter->useful-rdkit-utils) (2.3.2.post1)
# Requirement already satisfied: webencodings in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from bleach->nbconvert->jupyter->useful-rdkit-utils) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from packaging->ipykernel->jupyter->useful-rdkit-utils) (3.0.9)
# Requirement already satisfied: tqdm in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from pystow->useful-rdkit-utils) (4.64.0)
# Requirement already satisfied: click in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from pystow->useful-rdkit-utils) (8.1.3)
# Requirement already satisfied: tomli>=1.0.0 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from pytest->useful-rdkit-utils) (2.0.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from pytest->useful-rdkit-utils) (1.0.0)
# Requirement already satisfied: iniconfig in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from pytest->useful-rdkit-utils) (1.1.1)
# Requirement already satisfied: py>=1.8.2 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from pytest->useful-rdkit-utils) (1.11.0)
# Requirement already satisfied: qtpy>=2.0.1 in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from qtconsole->jupyter->useful-rdkit-utils) (2.1.0)
# Requirement already satisfied: executing in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->useful-rdkit-utils) (0.8.3)
# Requirement already satisfied: pure-eval in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->useful-rdkit-utils) (0.2.2)
# Requirement already satisfied: asttokens in /Users/pwalters/opt/anaconda3/envs/rdkit_2022_06/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->useful-rdkit-utils) (2.0.5)

# %% [markdown]
# Download the scaffold_finder library from GitHub.

# %%
import requests
lib_file = requests.get("https://raw.githubusercontent.com/PatWalters/practical_cheminformatics_tutorials/main/sar_analysis/scaffold_finder.py")
ofs = open("scaffold_finder.py","w")
print(lib_file.text,file=ofs)
ofs.close()

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem.rdDepictor import Compute2DCoords
from io import StringIO
import mols2grid
from scaffold_finder import generate_fragments, find_scaffolds, get_molecules_with_scaffold, cleanup_fragment

# %% [markdown]
# ### A Simple Example
#
# As an example, let's consider four molecules from the paper by [Naveja, Vogt, Stumpfe, Medina-Franco, Bajorath](https://pubs.acs.org/doi/full/10.1021/acsomega.8b03390).

# %%
buff = """NS(=O)(=O)C1=CC=C(C=C1)C1=C(C(=O)NC1=O)C1=CC=CC=C1,mol_001
CN1C(=O)C(=C(C1=O)C1=CC=C(C=C1)S(N)(=O)=O)C1=CC=CC=C1,mol_002
COC1=CC=C(C=C1)C1=C(C(=O)N(C)C1=O)C1=CC=C(C=C1)S(N)(=O)=O,mol_003
COC1=CC=C(C=C1)C1=C(C(=O)NC1=O)C1=CC=C(C=C1)S(N)(=O)=O,mol_004
"""
fs = StringIO(buff)
df = pd.read_csv(fs,names=["SMILES","Name"])
df['mol'] = df.SMILES.apply(Chem.MolFromSmiles)

# %%
mols2grid.display(df,mol_col="mol",size=(200,200))
# Out:
# <iframe class="mols2grid-iframe" width=100% height="370" frameborder="0" srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#       #mols2grid.gridcontainer {
#         display: block;
#         padding-left: 1em;
#         max-width: 1020px;
#         width: 1020px;
#       }
#       #mols2grid .cell {
#         border: 1px solid #cccccc;
#         text-align: center;
#         vertical-align: top;
#         max-width: 200px;
#         width: 200px;
#         font-family: &#x27;DejaVu&#x27;, sans-serif;
#         font-size: 12pt;
#         padding: 0;
#         margin: 0;
#         float: left;
#       }
#       #mols2grid .cell:hover {
#         background-color: #e7e7e7;
#       }
#       #mols2grid .cell img, #mols2grid .cell svg {
#         max-width: 100%;
#         height: auto;
#         padding: 0;
#       }
#       #mols2grid .data {
#         overflow: hidden;
#         white-space: nowrap;
#         text-overflow: ellipsis;
#         display: block;
#       }
#       #mols2grid .arrow-asc:after {
#         content: &#x27;↑&#x27;;
#         text-align: right;
#         float:right;
#       }
#       #mols2grid .arrow-desc:after {
#         content: &#x27;↓&#x27;;
#         text-align: right;
#         float:right;
#       }
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/list.js/2.3.1/list.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/css/bootstrap.min.css&quot; integrity=&quot;sha384-B0vP5xmATw1+K9KRQjQERJvTumQW0nPEzvF6L/Z6nronJ3oUOFUFpCjEUQouq2+l&quot; crossorigin=&quot;anonymous&quot;&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.5.1.slim.min.js&quot; integrity=&quot;sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@rdkit/rdkit@2021.3.2/Code/MinimalLib/dist/RDKit_minimal.js&quot;&gt;&lt;/script&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mols2grid&quot; class=&quot;gridcontainer&quot;&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;div class=&quot;list&quot;&gt;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-SMILES&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Name&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-mols2grid-id-copy&quot;&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#       &lt;/div&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;ul class=&quot;pagination pt-3 pl-3 col&quot;&gt;&lt;/ul&gt;
#         &lt;div class=&quot;dropdown float-right col-1 py-3 mr-4&quot;&gt;
#           &lt;button class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; id=&quot;sortDropdown&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;
#             Sort by
#           &lt;/button&gt;
#           &lt;div class=&quot;dropdown-menu&quot; aria-labelledby=&quot;sortDropdownMenu&quot;&gt;
#
#
#             &lt;button class=&quot;dropdown-item sort-btn arrow-asc active&quot; type=&quot;button&quot; data-name=&quot;mols2grid-id&quot;&gt;Index&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-SMILES&quot;&gt;Smiles&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-Name&quot;&gt;Name&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-mols2grid-id&quot;&gt;Mols2grid-id&lt;/button&gt;
#
#
#           &lt;/div&gt;
#         &lt;/div&gt;
#         &lt;div class=&quot;input-group float-right col-4 py-3 mr-3 ml-2&quot;&gt;
#           &lt;input type=&quot;text&quot; id=&quot;searchbar&quot; class=&quot;form-control&quot; placeholder=&quot;Search&quot; aria-label=&quot;Search&quot; aria-describedby=&quot;basic-addon1&quot;&gt;
#           &lt;div class=&quot;input-group-append&quot;&gt;
#             &lt;button id=&quot;searchBtn&quot; class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;🔎&lt;/button&gt;
#             &lt;div class=&quot;dropdown-menu dropdown-menu-right&quot;&gt;
#               &lt;button id=&quot;txtSearch&quot; class=&quot;search-btn dropdown-item active&quot;&gt;Text&lt;/button&gt;
#               &lt;button id=&quot;smartsSearch&quot; class=&quot;search-btn dropdown-item&quot;&gt;SMARTS&lt;/button&gt;
#             &lt;/div&gt;
#           &lt;/div&gt;
#         &lt;/div&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#     &lt;script&gt;
#       // RDKit
#       onRuntimeInitialized: initRDKitModule().then(function(instance) {
#         RDKitModule = instance;
#         console.log(&#x27;RDKit version: &#x27; + RDKitModule.version());
#       });
#       // pages
#       var listObj = new List(&#x27;mols2grid&#x27;,
#         {
#           valueNames: [{data: [&#x27;mols2grid-id&#x27;]}, &#x27;data-img&#x27;, &#x27;data-Name&#x27;, &#x27;data-SMILES&#x27;, &#x27;data-mols2grid-id&#x27;, &#x27;data-mols2grid-id-copy&#x27;],
#           item: &#x27;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-SMILES&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Name&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-mols2grid-id-copy&quot;&gt;&lt;/div&gt;&lt;/div&gt;&#x27;,
#           page: 15,
#           pagination: {
#             name: &quot;pagination&quot;,
#             item: &#x27;&lt;li class=&quot;page-item&quot;&gt;&lt;a class=&quot;page page-link&quot; href=&quot;#&quot; onclick=&quot;event.preventDefault()&quot;&gt;&lt;/a&gt;&lt;/li&gt;&#x27;,
#             innerWindow: 1,
#             outerWindow: 1,
#           },
#         }
#       );
#       listObj.remove(&quot;mols2grid-id&quot;, &quot;0&quot;)
#       listObj.add([{&quot;data-img&quot;: &quot;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;iso-8859-1&#x27;?&gt;\n&lt;svg version=&#x27;1.1&#x27; baseProfile=&#x27;full&#x27;\n              xmlns=&#x27;http://www.w3.org/2000/svg&#x27;\n                      xmlns:rdkit=&#x27;http://www.rdkit.org/xml&#x27;\n                      xmlns:xlink=&#x27;http://www.w3.org/1999/xlink&#x27;\n                  xml:space=&#x27;preserve&#x27;\nwidth=&#x27;200px&#x27; height=&#x27;200px&#x27; viewBox=&#x27;0 0 200 200&#x27;&gt;\n&lt;!-- END OF HEADER --&gt;\n&lt;rect style=&#x27;opacity:1.0;fill:#FFFFFF;stroke:none&#x27; width=&#x27;200.0&#x27; height=&#x27;200.0&#x27; x=&#x27;0.0&#x27; y=&#x27;0.0&#x27;&gt; &lt;/rect&gt;\n&lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 32.4,137.9 L 38.1,134.6&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#0000FF;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 38.1,134.6 L 43.9,131.2&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#CCCC00;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 49.7,135.7 L 52.1,139.9&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#CCCC00;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#

# %% [markdown]
# We'll begin with the first molecule.

# %%
m0 = df.mol.values[0]
m0

# %% [markdown]
# First, we'll convert the molecule to fragments.

# %%
m0_frag_df = generate_fragments(m0)
m0_frag_df
# Out:
#                                        Scaffold  NumAtoms  NumRgroupgs
# 0              O=C1NC(=O)C(c2ccccc2)=C1c1ccccc1        19            1
# 1            NS(=O)(=O)c1ccc(C2=CC(=O)NC2=O)cc1        17            1
# 2  NS(=O)(=O)c1ccc(C2=C(c3ccccc3)C(=O)NC2=O)cc1        23            1

# %%
mols2grid.display(m0_frag_df,smiles_col="Scaffold")
# Out:
# <iframe class="mols2grid-iframe" width=100% height="314" frameborder="0" srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#       #mols2grid.gridcontainer {
#         display: block;
#         padding-left: 1em;
#         max-width: 820px;
#         width: 820px;
#       }
#       #mols2grid .cell {
#         border: 1px solid #cccccc;
#         text-align: center;
#         vertical-align: top;
#         max-width: 160px;
#         width: 160px;
#         font-family: &#x27;DejaVu&#x27;, sans-serif;
#         font-size: 12pt;
#         padding: 0;
#         margin: 0;
#         float: left;
#       }
#       #mols2grid .cell:hover {
#         background-color: #e7e7e7;
#       }
#       #mols2grid .cell img, #mols2grid .cell svg {
#         max-width: 100%;
#         height: auto;
#         padding: 0;
#       }
#       #mols2grid .data {
#         overflow: hidden;
#         white-space: nowrap;
#         text-overflow: ellipsis;
#         display: block;
#       }
#       #mols2grid .arrow-asc:after {
#         content: &#x27;↑&#x27;;
#         text-align: right;
#         float:right;
#       }
#       #mols2grid .arrow-desc:after {
#         content: &#x27;↓&#x27;;
#         text-align: right;
#         float:right;
#       }
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/list.js/2.3.1/list.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/css/bootstrap.min.css&quot; integrity=&quot;sha384-B0vP5xmATw1+K9KRQjQERJvTumQW0nPEzvF6L/Z6nronJ3oUOFUFpCjEUQouq2+l&quot; crossorigin=&quot;anonymous&quot;&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.5.1.slim.min.js&quot; integrity=&quot;sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@rdkit/rdkit@2021.3.2/Code/MinimalLib/dist/RDKit_minimal.js&quot;&gt;&lt;/script&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mols2grid&quot; class=&quot;gridcontainer&quot;&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;div class=&quot;list&quot;&gt;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Scaffold&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-NumAtoms&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-NumRgroupgs&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-mols2grid-id-copy&quot;&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#       &lt;/div&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;ul class=&quot;pagination pt-3 pl-3 col&quot;&gt;&lt;/ul&gt;
#         &lt;div class=&quot;dropdown float-right col-1 py-3 mr-4&quot;&gt;
#           &lt;button class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; id=&quot;sortDropdown&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;
#             Sort by
#           &lt;/button&gt;
#           &lt;div class=&quot;dropdown-menu&quot; aria-labelledby=&quot;sortDropdownMenu&quot;&gt;
#
#
#             &lt;button class=&quot;dropdown-item sort-btn arrow-asc active&quot; type=&quot;button&quot; data-name=&quot;mols2grid-id&quot;&gt;Index&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-Scaffold&quot;&gt;Scaffold&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-NumAtoms&quot;&gt;Numatoms&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-NumRgroupgs&quot;&gt;Numrgroupgs&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-mols2grid-id&quot;&gt;Mols2grid-id&lt;/button&gt;
#
#
#           &lt;/div&gt;
#         &lt;/div&gt;
#         &lt;div class=&quot;input-group float-right col-4 py-3 mr-3 ml-2&quot;&gt;
#           &lt;input type=&quot;text&quot; id=&quot;searchbar&quot; class=&quot;form-control&quot; placeholder=&quot;Search&quot; aria-label=&quot;Search&quot; aria-describedby=&quot;basic-addon1&quot;&gt;
#           &lt;div class=&quot;input-group-append&quot;&gt;
#             &lt;button id=&quot;searchBtn&quot; class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;🔎&lt;/button&gt;
#             &lt;div class=&quot;dropdown-menu dropdown-menu-right&quot;&gt;
#               &lt;button id=&quot;txtSearch&quot; class=&quot;search-btn dropdown-item active&quot;&gt;Text&lt;/button&gt;
#               &lt;button id=&quot;smartsSearch&quot; class=&quot;search-btn dropdown-item&quot;&gt;SMARTS&lt;/button&gt;
#             &lt;/div&gt;
#           &lt;/div&gt;
#         &lt;/div&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#     &lt;script&gt;
#       // RDKit
#       onRuntimeInitialized: initRDKitModule().then(function(instance) {
#         RDKitModule = instance;
#         console.log(&#x27;RDKit version: &#x27; + RDKitModule.version());
#       });
#       // pages
#       var listObj = new List(&#x27;mols2grid&#x27;,
#         {
#           valueNames: [{data: [&#x27;mols2grid-id&#x27;]}, &#x27;data-Scaffold&#x27;, &#x27;data-img&#x27;, &#x27;data-NumRgroupgs&#x27;, &#x27;data-NumAtoms&#x27;, &#x27;data-mols2grid-id&#x27;, &#x27;data-mols2grid-id-copy&#x27;],
#           item: &#x27;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Scaffold&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-NumAtoms&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-NumRgroupgs&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-mols2grid-id-copy&quot;&gt;&lt;/div&gt;&lt;/div&gt;&#x27;,
#           page: 15,
#           pagination: {
#             name: &quot;pagination&quot;,
#             item: &#x27;&lt;li class=&quot;page-item&quot;&gt;&lt;a class=&quot;page page-link&quot; href=&quot;#&quot; onclick=&quot;event.preventDefault()&quot;&gt;&lt;/a&gt;&lt;/li&gt;&#x27;,
#             innerWindow: 1,
#             outerWindow: 1,
#           },
#         }
#       );
#       listObj.remove(&quot;mols2grid-id&quot;, &quot;0&quot;)
#       listObj.add([{&quot;data-Scaffold&quot;: &quot;O=C1NC(=O)C(c2ccccc2)=C1c1ccccc1&quot;, &quot;data-img&quot;: &quot;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;iso-8859-1&#x27;?&gt;\n&lt;svg version=&#x27;1.1&#x27; baseProfile=&#x27;full&#x27;\n              xmlns=&#x27;http://www.w3.org/2000/svg&#x27;\n                      xmlns:rdkit=&#x27;http://www.rdkit.org/xml&#x27;\n                      xmlns:xlink=&#x27;http://www.w3.org/1999/xlink&#x27;\n                  xml:space=&#x27;preserve&#x27;\nwidth=&#x27;160px&#x27; height=&#x27;120px&#x27; viewBox=&#x27;0 0 160 120&#x27;&gt;\n&lt;!-- END OF HEADER --&gt;\n&lt;rect style=&#x27;opacity:1.0;fill:#FFFFFF;stroke:none&#x27; width=&#x27;160.0&#x27; height=&#x27;120.0&#x27; x=&#x27;0.0&#x27; y=&#x27;0.0&#x27;&gt; &lt;/rect&gt;\n&lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 127.1,41.0 L 118.5,40.1&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#FF0000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt

# %% [markdown]
# We can do the same thing with the second molecule.

# %%
m1 = df.mol.values[1]
m1

# %%
m1_frag_df = generate_fragments(m1)
m1_frag_df
# Out:
#                                           Scaffold  NumAtoms  NumRgroupgs
# 0     NS(=O)(=O)c1ccc(C2=C(c3ccccc3)C(=O)NC2=O)cc1        23            1
# 1               NS(=O)(=O)c1ccc(C2=CC(=O)NC2=O)cc1        17            2
# 2                 O=C1NC(=O)C(c2ccccc2)=C1c1ccccc1        19            2
# 3            CN1C(=O)C=C(c2ccc(S(N)(=O)=O)cc2)C1=O        18            1
# 4              CN1C(=O)C(c2ccccc2)=C(c2ccccc2)C1=O        20            1
# 5  CN1C(=O)C(c2ccccc2)=C(c2ccc(S(N)(=O)=O)cc2)C1=O        24            1

# %%
mols2grid.display(m1_frag_df,smiles_col="Scaffold")
# Out:
# <iframe class="mols2grid-iframe" width=100% height="558" frameborder="0" srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#       #mols2grid.gridcontainer {
#         display: block;
#         padding-left: 1em;
#         max-width: 820px;
#         width: 820px;
#       }
#       #mols2grid .cell {
#         border: 1px solid #cccccc;
#         text-align: center;
#         vertical-align: top;
#         max-width: 160px;
#         width: 160px;
#         font-family: &#x27;DejaVu&#x27;, sans-serif;
#         font-size: 12pt;
#         padding: 0;
#         margin: 0;
#         float: left;
#       }
#       #mols2grid .cell:hover {
#         background-color: #e7e7e7;
#       }
#       #mols2grid .cell img, #mols2grid .cell svg {
#         max-width: 100%;
#         height: auto;
#         padding: 0;
#       }
#       #mols2grid .data {
#         overflow: hidden;
#         white-space: nowrap;
#         text-overflow: ellipsis;
#         display: block;
#       }
#       #mols2grid .arrow-asc:after {
#         content: &#x27;↑&#x27;;
#         text-align: right;
#         float:right;
#       }
#       #mols2grid .arrow-desc:after {
#         content: &#x27;↓&#x27;;
#         text-align: right;
#         float:right;
#       }
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/list.js/2.3.1/list.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/css/bootstrap.min.css&quot; integrity=&quot;sha384-B0vP5xmATw1+K9KRQjQERJvTumQW0nPEzvF6L/Z6nronJ3oUOFUFpCjEUQouq2+l&quot; crossorigin=&quot;anonymous&quot;&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.5.1.slim.min.js&quot; integrity=&quot;sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@rdkit/rdkit@2021.3.2/Code/MinimalLib/dist/RDKit_minimal.js&quot;&gt;&lt;/script&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mols2grid&quot; class=&quot;gridcontainer&quot;&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;div class=&quot;list&quot;&gt;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Scaffold&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-NumAtoms&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-NumRgroupgs&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-mols2grid-id-copy&quot;&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#       &lt;/div&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;ul class=&quot;pagination pt-3 pl-3 col&quot;&gt;&lt;/ul&gt;
#         &lt;div class=&quot;dropdown float-right col-1 py-3 mr-4&quot;&gt;
#           &lt;button class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; id=&quot;sortDropdown&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;
#             Sort by
#           &lt;/button&gt;
#           &lt;div class=&quot;dropdown-menu&quot; aria-labelledby=&quot;sortDropdownMenu&quot;&gt;
#
#
#             &lt;button class=&quot;dropdown-item sort-btn arrow-asc active&quot; type=&quot;button&quot; data-name=&quot;mols2grid-id&quot;&gt;Index&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-Scaffold&quot;&gt;Scaffold&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-NumAtoms&quot;&gt;Numatoms&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-NumRgroupgs&quot;&gt;Numrgroupgs&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-mols2grid-id&quot;&gt;Mols2grid-id&lt;/button&gt;
#
#
#           &lt;/div&gt;
#         &lt;/div&gt;
#         &lt;div class=&quot;input-group float-right col-4 py-3 mr-3 ml-2&quot;&gt;
#           &lt;input type=&quot;text&quot; id=&quot;searchbar&quot; class=&quot;form-control&quot; placeholder=&quot;Search&quot; aria-label=&quot;Search&quot; aria-describedby=&quot;basic-addon1&quot;&gt;
#           &lt;div class=&quot;input-group-append&quot;&gt;
#             &lt;button id=&quot;searchBtn&quot; class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;🔎&lt;/button&gt;
#             &lt;div class=&quot;dropdown-menu dropdown-menu-right&quot;&gt;
#               &lt;button id=&quot;txtSearch&quot; class=&quot;search-btn dropdown-item active&quot;&gt;Text&lt;/button&gt;
#               &lt;button id=&quot;smartsSearch&quot; class=&quot;search-btn dropdown-item&quot;&gt;SMARTS&lt;/button&gt;
#             &lt;/div&gt;
#           &lt;/div&gt;
#         &lt;/div&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#     &lt;script&gt;
#       // RDKit
#       onRuntimeInitialized: initRDKitModule().then(function(instance) {
#         RDKitModule = instance;
#         console.log(&#x27;RDKit version: &#x27; + RDKitModule.version());
#       });
#       // pages
#       var listObj = new List(&#x27;mols2grid&#x27;,
#         {
#           valueNames: [{data: [&#x27;mols2grid-id&#x27;]}, &#x27;data-Scaffold&#x27;, &#x27;data-img&#x27;, &#x27;data-NumRgroupgs&#x27;, &#x27;data-NumAtoms&#x27;, &#x27;data-mols2grid-id&#x27;, &#x27;data-mols2grid-id-copy&#x27;],
#           item: &#x27;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Scaffold&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-NumAtoms&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-NumRgroupgs&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-mols2grid-id-copy&quot;&gt;&lt;/div&gt;&lt;/div&gt;&#x27;,
#           page: 15,
#           pagination: {
#             name: &quot;pagination&quot;,
#             item: &#x27;&lt;li class=&quot;page-item&quot;&gt;&lt;a class=&quot;page page-link&quot; href=&quot;#&quot; onclick=&quot;event.preventDefault()&quot;&gt;&lt;/a&gt;&lt;/li&gt;&#x27;,
#             innerWindow: 1,
#             outerWindow: 1,
#           },
#         }
#       );
#       listObj.remove(&quot;mols2grid-id&quot;, &quot;0&quot;)
#       listObj.add([{&quot;data-Scaffold&quot;: &quot;NS(=O)(=O)c1ccc(C2=C(c3ccccc3)C(=O)NC2=O)cc1&quot;, &quot;data-img&quot;: &quot;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;iso-8859-1&#x27;?&gt;\n&lt;svg version=&#x27;1.1&#x27; baseProfile=&#x27;full&#x27;\n              xmlns=&#x27;http://www.w3.org/2000/svg&#x27;\n                      xmlns:rdkit=&#x27;http://www.rdkit.org/xml&#x27;\n                      xmlns:xlink=&#x27;http://www.w3.org/1999/xlink&#x27;\n                  xml:space=&#x27;preserve&#x27;\nwidth=&#x27;160px&#x27; height=&#x27;120px&#x27; viewBox=&#x27;0 0 160 120&#x27;&gt;\n&lt;!-- END OF HEADER --&gt;\n&lt;rect style=&#x27;opacity:1.0;fill:#FFFFFF;stroke:none&#x27; width=&#x27;160.0&#x27; height=&#x27;120.0&#x27; x=&#x27;0.0&#x27; y=&#x27;0.0&#x27;&gt; &lt;/rect&gt;\n&lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 25.9,90.3 L 30.5,87.7&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#0000FF;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27;

# %% [markdown]
# Let's combine the fragments from m0 and m1 into one dataframe.

# %%
m0m1_frag_df = pd.concat([m0_frag_df,m1_frag_df])

# %% [markdown]
# We can then use Pandas **groupby** to record the frequency of occurrence of each fragment.

# %%
scaffold_list = []
for k,v in m0m1_frag_df.groupby("Scaffold"):
    scaffold_list.append([k,len(v),v.NumAtoms.values[0]])
scaffold_df = pd.DataFrame(scaffold_list,columns=["Scaffold","Count","NumAtoms"])

# %%
scaffold_df.sort_values(["Count","NumAtoms"],ascending=[False, False],inplace=True)

# %% [markdown]
# The table below records the frequency of occurrence of each fragment.

# %%
mols2grid.display(scaffold_df,smiles_col="Scaffold",subset=["img","Count","NumAtoms"])
# Out:
# <iframe class="mols2grid-iframe" width=100% height="414" frameborder="0" srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#       #mols2grid.gridcontainer {
#         display: block;
#         padding-left: 1em;
#         max-width: 820px;
#         width: 820px;
#       }
#       #mols2grid .cell {
#         border: 1px solid #cccccc;
#         text-align: center;
#         vertical-align: top;
#         max-width: 160px;
#         width: 160px;
#         font-family: &#x27;DejaVu&#x27;, sans-serif;
#         font-size: 12pt;
#         padding: 0;
#         margin: 0;
#         float: left;
#       }
#       #mols2grid .cell:hover {
#         background-color: #e7e7e7;
#       }
#       #mols2grid .cell img, #mols2grid .cell svg {
#         max-width: 100%;
#         height: auto;
#         padding: 0;
#       }
#       #mols2grid .data {
#         overflow: hidden;
#         white-space: nowrap;
#         text-overflow: ellipsis;
#         display: block;
#       }
#       #mols2grid .arrow-asc:after {
#         content: &#x27;↑&#x27;;
#         text-align: right;
#         float:right;
#       }
#       #mols2grid .arrow-desc:after {
#         content: &#x27;↓&#x27;;
#         text-align: right;
#         float:right;
#       }
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/list.js/2.3.1/list.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/css/bootstrap.min.css&quot; integrity=&quot;sha384-B0vP5xmATw1+K9KRQjQERJvTumQW0nPEzvF6L/Z6nronJ3oUOFUFpCjEUQouq2+l&quot; crossorigin=&quot;anonymous&quot;&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.5.1.slim.min.js&quot; integrity=&quot;sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@rdkit/rdkit@2021.3.2/Code/MinimalLib/dist/RDKit_minimal.js&quot;&gt;&lt;/script&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mols2grid&quot; class=&quot;gridcontainer&quot;&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;div class=&quot;list&quot;&gt;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Count&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-NumAtoms&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Scaffold&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#       &lt;/div&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;ul class=&quot;pagination pt-3 pl-3 col&quot;&gt;&lt;/ul&gt;
#         &lt;div class=&quot;dropdown float-right col-1 py-3 mr-4&quot;&gt;
#           &lt;button class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; id=&quot;sortDropdown&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;
#             Sort by
#           &lt;/button&gt;
#           &lt;div class=&quot;dropdown-menu&quot; aria-labelledby=&quot;sortDropdownMenu&quot;&gt;
#
#
#             &lt;button class=&quot;dropdown-item sort-btn arrow-asc active&quot; type=&quot;button&quot; data-name=&quot;mols2grid-id&quot;&gt;Index&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-Count&quot;&gt;Count&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-NumAtoms&quot;&gt;Numatoms&lt;/button&gt;
#
#
#           &lt;/div&gt;
#         &lt;/div&gt;
#         &lt;div class=&quot;input-group float-right col-4 py-3 mr-3 ml-2&quot;&gt;
#           &lt;input type=&quot;text&quot; id=&quot;searchbar&quot; class=&quot;form-control&quot; placeholder=&quot;Search&quot; aria-label=&quot;Search&quot; aria-describedby=&quot;basic-addon1&quot;&gt;
#           &lt;div class=&quot;input-group-append&quot;&gt;
#             &lt;button id=&quot;searchBtn&quot; class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;🔎&lt;/button&gt;
#             &lt;div class=&quot;dropdown-menu dropdown-menu-right&quot;&gt;
#               &lt;button id=&quot;txtSearch&quot; class=&quot;search-btn dropdown-item active&quot;&gt;Text&lt;/button&gt;
#               &lt;button id=&quot;smartsSearch&quot; class=&quot;search-btn dropdown-item&quot;&gt;SMARTS&lt;/button&gt;
#             &lt;/div&gt;
#           &lt;/div&gt;
#         &lt;/div&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#     &lt;script&gt;
#       // RDKit
#       onRuntimeInitialized: initRDKitModule().then(function(instance) {
#         RDKitModule = instance;
#         console.log(&#x27;RDKit version: &#x27; + RDKitModule.version());
#       });
#       // pages
#       var listObj = new List(&#x27;mols2grid&#x27;,
#         {
#           valueNames: [{data: [&#x27;mols2grid-id&#x27;]}, &#x27;data-Count&#x27;, &#x27;data-img&#x27;, &#x27;data-NumAtoms&#x27;, &#x27;data-Scaffold&#x27;],
#           item: &#x27;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Count&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-NumAtoms&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Scaffold&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&#x27;,
#           page: 15,
#           pagination: {
#             name: &quot;pagination&quot;,
#             item: &#x27;&lt;li class=&quot;page-item&quot;&gt;&lt;a class=&quot;page page-link&quot; href=&quot;#&quot; onclick=&quot;event.preventDefault()&quot;&gt;&lt;/a&gt;&lt;/li&gt;&#x27;,
#             innerWindow: 1,
#             outerWindow: 1,
#           },
#         }
#       );
#       listObj.remove(&quot;mols2grid-id&quot;, &quot;0&quot;)
#       listObj.add([{&quot;data-Scaffold&quot;: &quot;NS(=O)(=O)c1ccc(C2=C(c3ccccc3)C(=O)NC2=O)cc1&quot;, &quot;data-img&quot;: &quot;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;iso-8859-1&#x27;?&gt;\n&lt;svg version=&#x27;1.1&#x27; baseProfile=&#x27;full&#x27;\n              xmlns=&#x27;http://www.w3.org/2000/svg&#x27;\n                      xmlns:rdkit=&#x27;http://www.rdkit.org/xml&#x27;\n                      xmlns:xlink=&#x27;http://www.w3.org/1999/xlink&#x27;\n                  xml:space=&#x27;preserve&#x27;\nwidth=&#x27;160px&#x27; height=&#x27;120px&#x27; viewBox=&#x27;0 0 160 120&#x27;&gt;\n&lt;!-- END OF HEADER --&gt;\n&lt;rect style=&#x27;opacity:1.0;fill:#FFFFFF;stroke:none&#x27; width=&#x27;160.0&#x27; height=&#x27;120.0&#x27; x=&#x27;0.0&#x27; y=&#x27;0.0&#x27;&gt; &lt;/rect&gt;\n&lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 25.9,90.3 L 30.5,87.7&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#0000FF;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 30.5,87.7 L 35.1,85.0&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#CCCC00;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 39.7,88.6 L 41.7,91.9&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#CCCC00;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 41.7,91.9 L 43.6,95.2&#x27;

# %% [markdown]
# We can use the function **find_scaffolds** to find scaffolds in the set of four molecules above.

# %%
mol_df, scaf_df = find_scaffolds(df)
mols2grid.display(scaf_df,smiles_col="Scaffold",subset=["img","Count","NumAtoms"])
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# <iframe class="mols2grid-iframe" width=100% height="586" frameborder="0" srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#       #mols2grid.gridcontainer {
#         display: block;
#         padding-left: 1em;
#         max-width: 820px;
#         width: 820px;
#       }
#       #mols2grid .cell {
#         border: 1px solid #cccccc;
#         text-align: center;
#         vertical-align: top;
#         max-width: 160px;
#         width: 160px;
#         font-family: &#x27;DejaVu&#x27;, sans-serif;
#         font-size: 12pt;
#         padding: 0;
#         margin: 0;
#         float: left;
#       }
#       #mols2grid .cell:hover {
#         background-color: #e7e7e7;
#       }
#       #mols2grid .cell img, #mols2grid .cell svg {
#         max-width: 100%;
#         height: auto;
#         padding: 0;
#       }
#       #mols2grid .data {
#         overflow: hidden;
#         white-space: nowrap;
#         text-overflow: ellipsis;
#         display: block;
#       }
#       #mols2grid .arrow-asc:after {
#         content: &#x27;↑&#x27;;
#         text-align: right;
#         float:right;
#       }
#       #mols2grid .arrow-desc:after {
#         content: &#x27;↓&#x27;;
#         text-align: right;
#         float:right;
#       }
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/list.js/2.3.1/list.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/css/bootstrap.min.css&quot; integrity=&quot;sha384-B0vP5xmATw1+K9KRQjQERJvTumQW0nPEzvF6L/Z6nronJ3oUOFUFpCjEUQouq2+l&quot; crossorigin=&quot;anonymous&quot;&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.5.1.slim.min.js&quot; integrity=&quot;sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@rdkit/rdkit@2021.3.2/Code/MinimalLib/dist/RDKit_minimal.js&quot;&gt;&lt;/script&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mols2grid&quot; class=&quot;gridcontainer&quot;&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;div class=&quot;list&quot;&gt;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Count&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-NumAtoms&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Scaffold&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#       &lt;/div&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;ul class=&quot;pagination pt-3 pl-3 col&quot;&gt;&lt;/ul&gt;
#         &lt;div class=&quot;dropdown float-right col-1 py-3 mr-4&quot;&gt;
#           &lt;button class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; id=&quot;sortDropdown&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;
#             Sort by
#           &lt;/button&gt;
#           &lt;div class=&quot;dropdown-menu&quot; aria-labelledby=&quot;sortDropdownMenu&quot;&gt;
#
#
#             &lt;button class=&quot;dropdown-item sort-btn arrow-asc active&quot; type=&quot;button&quot; data-name=&quot;mols2grid-id&quot;&gt;Index&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-Count&quot;&gt;Count&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-NumAtoms&quot;&gt;Numatoms&lt;/button&gt;
#
#
#           &lt;/div&gt;
#         &lt;/div&gt;
#         &lt;div class=&quot;input-group float-right col-4 py-3 mr-3 ml-2&quot;&gt;
#           &lt;input type=&quot;text&quot; id=&quot;searchbar&quot; class=&quot;form-control&quot; placeholder=&quot;Search&quot; aria-label=&quot;Search&quot; aria-describedby=&quot;basic-addon1&quot;&gt;
#           &lt;div class=&quot;input-group-append&quot;&gt;
#             &lt;button id=&quot;searchBtn&quot; class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;🔎&lt;/button&gt;
#             &lt;div class=&quot;dropdown-menu dropdown-menu-right&quot;&gt;
#               &lt;button id=&quot;txtSearch&quot; class=&quot;search-btn dropdown-item active&quot;&gt;Text&lt;/button&gt;
#               &lt;button id=&quot;smartsSearch&quot; class=&quot;search-btn dropdown-item&quot;&gt;SMARTS&lt;/button&gt;
#             &lt;/div&gt;
#           &lt;/div&gt;
#         &lt;/div&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#     &lt;script&gt;
#       // RDKit
#       onRuntimeInitialized: initRDKitModule().then(function(instance) {
#         RDKitModule = instance;
#         console.log(&#x27;RDKit version: &#x27; + RDKitModule.version());
#       });
#       // pages
#       var listObj = new List(&#x27;mols2grid&#x27;,
#         {
#           valueNames: [{data: [&#x27;mols2grid-id&#x27;]}, &#x27;data-Count&#x27;, &#x27;data-img&#x27;, &#x27;data-NumAtoms&#x27;, &#x27;data-Scaffold&#x27;],
#           item: &#x27;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Count&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-NumAtoms&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Scaffold&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&#x27;,
#           page: 15,
#           pagination: {
#             name: &quot;pagination&quot;,
#             item: &#x27;&lt;li class=&quot;page-item&quot;&gt;&lt;a class=&quot;page page-link&quot; href=&quot;#&quot; onclick=&quot;event.preventDefault()&quot;&gt;&lt;/a&gt;&lt;/li&gt;&#x27;,
#             innerWindow: 1,
#             outerWindow: 1,
#           },
#         }
#       );
#       listObj.remove(&quot;mols2grid-id&quot;, &quot;0&quot;)
#       listObj.add([{&quot;data-Scaffold&quot;: &quot;NS(=O)(=O)c1ccc(C2=C(c3ccccc3)C(=O)NC2=O)cc1&quot;, &quot;data-img&quot;: &quot;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;iso-8859-1&#x27;?&gt;\n&lt;svg version=&#x27;1.1&#x27; baseProfile=&#x27;full&#x27;\n              xmlns=&#x27;http://www.w3.org/2000/svg&#x27;\n                      xmlns:rdkit=&#x27;http://www.rdkit.org/xml&#x27;\n                      xmlns:xlink=&#x27;http://www.w3.org/1999/xlink&#x27;\n                  xml:space=&#x27;preserve&#x27;\nwidth=&#x27;160px&#x27; height=&#x27;120px&#x27; viewBox=&#x27;0 0 160 120&#x27;&gt;\n&lt;!-- END OF HEADER --&gt;\n&lt;rect style=&#x27;opacity:1.0;fill:#FFFFFF;stroke:none&#x27; width=&#x27;160.0&#x27; height=&#x27;120.0&#x27; x=&#x27;0.0&#x27; y=&#x27;0.0&#x27;&gt; &lt;/rect&gt;\n&lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 25.9,90.3 L 30.5,87.7&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#0000FF;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 30.5,87.7 L 35.1,85.0&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#CCCC00;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 39.7,88.6 L 41.7,91.9&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#CCCC00;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 41.7,91.9 L 43.6,95.2&#x27;

# %% [markdown]
# ### A More Substantial Example
# Identifying scaffolds in a set of four molecules is a somewhat trivial problem.  Let's take a look at a larger set of molecules from the ChEMBL database. We'll start by reading the input data.

# %%
# infile_url = "https://raw.githubusercontent.com/PatWalters/practical_cheminformatics_tutorials/main/data/CHEMBL208.smi"
infile_url = "../data/CHEMBL208.smi"
chembl208_df = pd.read_csv(infile_url,names=["SMILES","Name","pIC50"])
chembl208_df.head()
# Out:
#                                               SMILES          Name  pIC50
# 0                  O=c1[nH]c2ccc(-c3cccc(Cl)c3)cc2s1   CHEMBL94053   6.90
# 1  O=c1[nH]c2ccc(-c3cccc([N+](=O)[O-])c3)cc2n1Cc1...  CHEMBL327409   6.15
# 2    CC1=CC(C)(C)Nc2ccc(-c3cccc([N+](=O)[O-])c3)cc21   CHEMBL93027   7.70
# 3           CC(C)n1c(=O)[nH]c2ccc(-c3cccc(Cl)c3)cc21  CHEMBL329631   6.28
# 4  CC(C)n1c(=O)[nH]c2ccc(-c3cccc([N+](=O)[O-])c3)...  CHEMBL327444   6.28

# %% [markdown]
# First we'll add a column with RDKit molecules to the dataframe.

# %%
chembl208_df['mol'] = chembl208_df.SMILES.apply(Chem.MolFromSmiles)

# %% [markdown]
# Next, we can identify scaffolds.

# %%
mol_df, scaffold_df = find_scaffolds(chembl208_df)
# Out:
#   0%|          | 0/513 [00:00<?, ?it/s]

# %% [markdown]
# Let's take a look at the scaffolds

# %%
scaffold_df
# Out:
#                                         Scaffold  Count  NumAtoms
# 5012       CC1=CC(C)(C)Nc2ccc3c(c21)COc1ccccc1-3    108        21
# 4312          CC1(C)C=Cc2c(ccc3c2COc2ccccc2-3)N1     93        20
# 5396          CC1=CC(C)Nc2ccc3c(c21)COc1ccccc1-3     92        20
# 2555   C=C1Oc2ccccc2-c2ccc3c(c21)C(C)=CC(C)(C)N3     64        22
# 2556      C=C1Oc2ccccc2-c2ccc3c(c21)C(C)=CC(C)N3     50        21
# ...                                          ...    ...       ...
# 3933                   CC(C)n1c(=O)[nH]c2ccccc21      1        13
# 11729                O=[SH](=O)Nc1ccc2cc[nH]c2c1      1        13
# 7372                      CCn1c(=O)[nH]c2ccccc21      1        12
# 11001                      Cn1c(=O)[nH]c2ccccc21      1        11
# 11886                           c1ccc2[nH]ccc2c1      1         9
#
# [11890 rows x 3 columns]

# %%
mols2grid.display(scaffold_df.head(10),smiles_col="Scaffold",subset=["img","Count"])
# Out:
# <iframe class="mols2grid-iframe" width=100% height="366" frameborder="0" srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#       #mols2grid.gridcontainer {
#         display: block;
#         padding-left: 1em;
#         max-width: 820px;
#         width: 820px;
#       }
#       #mols2grid .cell {
#         border: 1px solid #cccccc;
#         text-align: center;
#         vertical-align: top;
#         max-width: 160px;
#         width: 160px;
#         font-family: &#x27;DejaVu&#x27;, sans-serif;
#         font-size: 12pt;
#         padding: 0;
#         margin: 0;
#         float: left;
#       }
#       #mols2grid .cell:hover {
#         background-color: #e7e7e7;
#       }
#       #mols2grid .cell img, #mols2grid .cell svg {
#         max-width: 100%;
#         height: auto;
#         padding: 0;
#       }
#       #mols2grid .data {
#         overflow: hidden;
#         white-space: nowrap;
#         text-overflow: ellipsis;
#         display: block;
#       }
#       #mols2grid .arrow-asc:after {
#         content: &#x27;↑&#x27;;
#         text-align: right;
#         float:right;
#       }
#       #mols2grid .arrow-desc:after {
#         content: &#x27;↓&#x27;;
#         text-align: right;
#         float:right;
#       }
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/list.js/2.3.1/list.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/css/bootstrap.min.css&quot; integrity=&quot;sha384-B0vP5xmATw1+K9KRQjQERJvTumQW0nPEzvF6L/Z6nronJ3oUOFUFpCjEUQouq2+l&quot; crossorigin=&quot;anonymous&quot;&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.5.1.slim.min.js&quot; integrity=&quot;sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@rdkit/rdkit@2021.3.2/Code/MinimalLib/dist/RDKit_minimal.js&quot;&gt;&lt;/script&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mols2grid&quot; class=&quot;gridcontainer&quot;&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;div class=&quot;list&quot;&gt;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Count&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Scaffold&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#       &lt;/div&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;ul class=&quot;pagination pt-3 pl-3 col&quot;&gt;&lt;/ul&gt;
#         &lt;div class=&quot;dropdown float-right col-1 py-3 mr-4&quot;&gt;
#           &lt;button class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; id=&quot;sortDropdown&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;
#             Sort by
#           &lt;/button&gt;
#           &lt;div class=&quot;dropdown-menu&quot; aria-labelledby=&quot;sortDropdownMenu&quot;&gt;
#
#
#             &lt;button class=&quot;dropdown-item sort-btn arrow-asc active&quot; type=&quot;button&quot; data-name=&quot;mols2grid-id&quot;&gt;Index&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-Count&quot;&gt;Count&lt;/button&gt;
#
#
#           &lt;/div&gt;
#         &lt;/div&gt;
#         &lt;div class=&quot;input-group float-right col-4 py-3 mr-3 ml-2&quot;&gt;
#           &lt;input type=&quot;text&quot; id=&quot;searchbar&quot; class=&quot;form-control&quot; placeholder=&quot;Search&quot; aria-label=&quot;Search&quot; aria-describedby=&quot;basic-addon1&quot;&gt;
#           &lt;div class=&quot;input-group-append&quot;&gt;
#             &lt;button id=&quot;searchBtn&quot; class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;🔎&lt;/button&gt;
#             &lt;div class=&quot;dropdown-menu dropdown-menu-right&quot;&gt;
#               &lt;button id=&quot;txtSearch&quot; class=&quot;search-btn dropdown-item active&quot;&gt;Text&lt;/button&gt;
#               &lt;button id=&quot;smartsSearch&quot; class=&quot;search-btn dropdown-item&quot;&gt;SMARTS&lt;/button&gt;
#             &lt;/div&gt;
#           &lt;/div&gt;
#         &lt;/div&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#     &lt;script&gt;
#       // RDKit
#       onRuntimeInitialized: initRDKitModule().then(function(instance) {
#         RDKitModule = instance;
#         console.log(&#x27;RDKit version: &#x27; + RDKitModule.version());
#       });
#       // pages
#       var listObj = new List(&#x27;mols2grid&#x27;,
#         {
#           valueNames: [{data: [&#x27;mols2grid-id&#x27;]}, &#x27;data-Count&#x27;, &#x27;data-img&#x27;, &#x27;data-Scaffold&#x27;],
#           item: &#x27;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Count&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Scaffold&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&#x27;,
#           page: 15,
#           pagination: {
#             name: &quot;pagination&quot;,
#             item: &#x27;&lt;li class=&quot;page-item&quot;&gt;&lt;a class=&quot;page page-link&quot; href=&quot;#&quot; onclick=&quot;event.preventDefault()&quot;&gt;&lt;/a&gt;&lt;/li&gt;&#x27;,
#             innerWindow: 1,
#             outerWindow: 1,
#           },
#         }
#       );
#       listObj.remove(&quot;mols2grid-id&quot;, &quot;0&quot;)
#       listObj.add([{&quot;data-Count&quot;: 108, &quot;data-img&quot;: &quot;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;iso-8859-1&#x27;?&gt;\n&lt;svg version=&#x27;1.1&#x27; baseProfile=&#x27;full&#x27;\n              xmlns=&#x27;http://www.w3.org/2000/svg&#x27;\n                      xmlns:rdkit=&#x27;http://www.rdkit.org/xml&#x27;\n                      xmlns:xlink=&#x27;http://www.w3.org/1999/xlink&#x27;\n                  xml:space=&#x27;preserve&#x27;\nwidth=&#x27;160px&#x27; height=&#x27;120px&#x27; viewBox=&#x27;0 0 160 120&#x27;&gt;\n&lt;!-- END OF HEADER --&gt;\n&lt;rect style=&#x27;opacity:1.0;fill:#FFFFFF;stroke:none&#x27; width=&#x27;160.0&#x27; height=&#x27;120.0&#x27; x=&#x27;0.0&#x27; y=&#x27;0.0&#x27;&gt; &lt;/rect&gt;\n&lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 45.3,90.5 L 45.4,69.8&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 45.4,69.8 L 27.5,59.4&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 45.4,66.2 L 30.7,57.6&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-2 atom-2 atom-3&#x27; d=&#x27;M 27.5,59.4 L 27.6,38.8&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-3 atom-3 atom-4&#x27; d=&#x27;M 27.6,38.8 L 20.6,19.3&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=

# %% [markdown]
# The scaffolds above are sorted by frequency.  We can look at the molecules containing the most frequently occurring scaffold by selecting the first scaffold in **scaffold_df**.

# %%
scaffold_0 = scaffold_df.Scaffold.values[0]

# %% [markdown]
# The function **get_molecules_with_scaffold** will return all the molecules containing the specified scaffold. This function returns two values.
# * A list of scaffolds with R-group substitution points labeled
# * A dataframe with molecules containing that scaffold

# %%
scaffold_smiles_list, chembl208_mol_df = get_molecules_with_scaffold(scaffold_0, mol_df, chembl208_df)

# %% [markdown]
# Let's look at the scaffold with R-group labels.

# %%
scaffold_mol = Chem.MolFromSmiles(scaffold_smiles_list[0])
scaffold_mol

# %%
clean_scaffold_mol, _ = cleanup_fragment(scaffold_mol)
Compute2DCoords(clean_scaffold_mol)
clean_scaffold_mol

# %% [markdown]
# With this scaffold in hand, we can generate aligned structures for the molecules.

# %%
chembl208_mol_df['mol'] = chembl208_mol_df.SMILES.apply(Chem.MolFromSmiles)

# %%
for mol in chembl208_mol_df.mol:
    AllChem.GenerateDepictionMatching2DStructure(mol,clean_scaffold_mol)

# %%
mols2grid.display(chembl208_mol_df.sort_values("pIC50",ascending=False),
                  mol_col='mol',use_coords=True, prerender=True, substruct_highlight=False,
                  transform={"pIC50" : lambda x: f"{x:.1f}"},
                  subset=["img","Name","pIC50"])
# Out:
# <iframe class="mols2grid-iframe" width=100% height="586" frameborder="0" srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#       #mols2grid.gridcontainer {
#         display: block;
#         padding-left: 1em;
#         max-width: 820px;
#         width: 820px;
#       }
#       #mols2grid .cell {
#         border: 1px solid #cccccc;
#         text-align: center;
#         vertical-align: top;
#         max-width: 160px;
#         width: 160px;
#         font-family: &#x27;DejaVu&#x27;, sans-serif;
#         font-size: 12pt;
#         padding: 0;
#         margin: 0;
#         float: left;
#       }
#       #mols2grid .cell:hover {
#         background-color: #e7e7e7;
#       }
#       #mols2grid .cell img, #mols2grid .cell svg {
#         max-width: 100%;
#         height: auto;
#         padding: 0;
#       }
#       #mols2grid .data {
#         overflow: hidden;
#         white-space: nowrap;
#         text-overflow: ellipsis;
#         display: block;
#       }
#       #mols2grid .arrow-asc:after {
#         content: &#x27;↑&#x27;;
#         text-align: right;
#         float:right;
#       }
#       #mols2grid .arrow-desc:after {
#         content: &#x27;↓&#x27;;
#         text-align: right;
#         float:right;
#       }
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/list.js/2.3.1/list.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/css/bootstrap.min.css&quot; integrity=&quot;sha384-B0vP5xmATw1+K9KRQjQERJvTumQW0nPEzvF6L/Z6nronJ3oUOFUFpCjEUQouq2+l&quot; crossorigin=&quot;anonymous&quot;&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.5.1.slim.min.js&quot; integrity=&quot;sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@rdkit/rdkit@2021.3.2/Code/MinimalLib/dist/RDKit_minimal.js&quot;&gt;&lt;/script&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mols2grid&quot; class=&quot;gridcontainer&quot;&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;div class=&quot;list&quot;&gt;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Name&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-pIC50&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-SMILES&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#       &lt;/div&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;ul class=&quot;pagination pt-3 pl-3 col&quot;&gt;&lt;/ul&gt;
#         &lt;div class=&quot;dropdown float-right col-1 py-3 mr-4&quot;&gt;
#           &lt;button class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; id=&quot;sortDropdown&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;
#             Sort by
#           &lt;/button&gt;
#           &lt;div class=&quot;dropdown-menu&quot; aria-labelledby=&quot;sortDropdownMenu&quot;&gt;
#
#
#             &lt;button class=&quot;dropdown-item sort-btn arrow-asc active&quot; type=&quot;button&quot; data-name=&quot;mols2grid-id&quot;&gt;Index&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-Name&quot;&gt;Name&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-pIC50&quot;&gt;Pic50&lt;/button&gt;
#
#
#           &lt;/div&gt;
#         &lt;/div&gt;
#         &lt;div class=&quot;input-group float-right col-4 py-3 mr-3 ml-2&quot;&gt;
#           &lt;input type=&quot;text&quot; id=&quot;searchbar&quot; class=&quot;form-control&quot; placeholder=&quot;Search&quot; aria-label=&quot;Search&quot; aria-describedby=&quot;basic-addon1&quot;&gt;
#           &lt;div class=&quot;input-group-append&quot;&gt;
#             &lt;button id=&quot;searchBtn&quot; class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;🔎&lt;/button&gt;
#             &lt;div class=&quot;dropdown-menu dropdown-menu-right&quot;&gt;
#               &lt;button id=&quot;txtSearch&quot; class=&quot;search-btn dropdown-item active&quot;&gt;Text&lt;/button&gt;
#               &lt;button id=&quot;smartsSearch&quot; class=&quot;search-btn dropdown-item&quot;&gt;SMARTS&lt;/button&gt;
#             &lt;/div&gt;
#           &lt;/div&gt;
#         &lt;/div&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#     &lt;script&gt;
#       // RDKit
#       onRuntimeInitialized: initRDKitModule().then(function(instance) {
#         RDKitModule = instance;
#         console.log(&#x27;RDKit version: &#x27; + RDKitModule.version());
#       });
#       // pages
#       var listObj = new List(&#x27;mols2grid&#x27;,
#         {
#           valueNames: [{data: [&#x27;mols2grid-id&#x27;]}, &#x27;data-img&#x27;, &#x27;data-pIC50&#x27;, &#x27;data-Name&#x27;, &#x27;data-SMILES&#x27;],
#           item: &#x27;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Name&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-pIC50&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-SMILES&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&#x27;,
#           page: 15,
#           pagination: {
#             name: &quot;pagination&quot;,
#             item: &#x27;&lt;li class=&quot;page-item&quot;&gt;&lt;a class=&quot;page page-link&quot; href=&quot;#&quot; onclick=&quot;event.preventDefault()&quot;&gt;&lt;/a&gt;&lt;/li&gt;&#x27;,
#             innerWindow: 1,
#             outerWindow: 1,
#           },
#         }
#       );
#       listObj.remove(&quot;mols2grid-id&quot;, &quot;0&quot;)
#       listObj.add([{&quot;data-img&quot;: &quot;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;iso-8859-1&#x27;?&gt;\n&lt;svg version=&#x27;1.1&#x27; baseProfile=&#x27;full&#x27;\n              xmlns=&#x27;http://www.w3.org/2000/svg&#x27;\n                      xmlns:rdkit=&#x27;http://www.rdkit.org/xml&#x27;\n                      xmlns:xlink=&#x27;http://www.w3.org/1999/xlink&#x27;\n                  xml:space=&#x27;preserve&#x27;\nwidth=&#x27;160px&#x27; height=&#x27;120px&#x27; viewBox=&#x27;0 0 160 120&#x27;&gt;\n&lt;!-- END OF HEADER --&gt;\n&lt;rect style=&#x27;opacity:1.0;fill:#FFFFFF;stroke:none&#x27; width=&#x27;160.0&#x27; height=&#x27;120.0&#x27; x=&#x27;0.0&#x27; y=&#x27;0.0&#x27;&gt; &lt;/rect&gt;\n&lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 51.5,68.4 L 51.0,52.9&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 51.0,52.9 L 36.8,44.7&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 51.0,50.0 L 39.3,43.3&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-2 atom-2 atom-3&#x27; d=&#x27;M 36.8,44.7 L 36.8,28.3&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:m
