# %% [markdown]
# ## Matched Molecular Series
# ### Introduction
#
# This notebook implements matched molecular series as described in these papers.
#
# Wawer, Mathias, and Jürgen Bajorath. "Local structural changes, global data views: graphical substructure− activity relationship trailing." Journal of Medicinal Chemistry **54** (2011): 2944-2951. https://doi.org/10.1021/jm200026b
#
# O’Boyle, Noel M., Jonas Boström, Roger A. Sayle, and Adrian Gill. "Using matched molecular series as a predictive tool to optimize biological activity." *Journal of Medicinal Chemistry*, **57** (2014): 2704-2713. [https://doi.org/10.1021/jm500022q](https://doi.org/10.1021/jm500022q)

# %% [markdown]
# ### Setup
# Check to see if we're running in Google Colab

# %%
import sys
IN_COLAB = 'google.colab' in sys.modules

# %% [markdown]
# Install the necessary Python packages

# %%
if IN_COLAB:
    # !pip install pandas requests rdkit useful_rdkit_utils mols2grid

# %% [markdown]
# Download the scaffold_finder library from GitHub.

# %%
if IN_COLAB:
    import requests
    lib_file = requests.get("https://raw.githubusercontent.com/PatWalters/practical_cheminformatics_tutorials/main/sar_analysis/scaffold_finder.py")
    ofs = open("scaffold_finder.py","w")
    print(lib_file.text,file=ofs)
    ofs.close()

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem.rdMMPA import FragmentMol
from rdkit.Chem.rdDepictor import Compute2DCoords
from scaffold_finder import generate_fragments, cleanup_fragment
from operator import itemgetter
import mols2grid
from rdkit.Chem.TemplateAlign import AlignMolToTemplate2D

# %% [markdown]
# Useful utility functions

# %%
def sort_fragments(mol):
    """
    Transform a molecule with multiple fragments into a list of molecules that is sorted by number of atoms
    from largest to smallest
    """
    frag_list = list(Chem.GetMolFrags(mol, asMols=True))
    frag_num_atoms_list = [(x.GetNumAtoms(), x) for x in frag_list]
    frag_num_atoms_list.sort(key=itemgetter(0), reverse=True)
    return [x[1] for x in frag_num_atoms_list]

# %% [markdown]
# ### Read Input
# Read the input data

# %%
infile_url = "../data/CHEMBL208.smi"
chembl208_df = pd.read_csv(infile_url,names=["SMILES","Name","pIC50"])

# %% [markdown]
# Add an RDKit molecule to the dataframe

# %%
chembl208_df['mol'] = chembl208_df.SMILES.apply(Chem.MolFromSmiles)

# %% [markdown]
# ### Generate Scaffold-Substituent Pairs
# Iterate over the molecules in the dataframe and transform to scaffold, substituent pairs

# %%
row_list = []
for smiles, name, pIC50, mol in chembl208_df.values:
    frag_list = FragmentMol(mol,maxCuts=1)
    for _,frag_mol in frag_list:
        pair_list = sort_fragments(frag_mol)
        row_list.append([smiles]+[Chem.MolToSmiles(x) for x in pair_list]+[name, pIC50])
row_df = pd.DataFrame(row_list,columns=["SMILES","Core","R_group","Name","pIC50"])
row_df
# Out:
#                                                  SMILES  \
# 0                     O=c1[nH]c2ccc(-c3cccc(Cl)c3)cc2s1
# 1                     O=c1[nH]c2ccc(-c3cccc(Cl)c3)cc2s1
# 2     O=c1[nH]c2ccc(-c3cccc([N+](=O)[O-])c3)cc2n1Cc1...
# 3     O=c1[nH]c2ccc(-c3cccc([N+](=O)[O-])c3)cc2n1Cc1...
# 4     O=c1[nH]c2ccc(-c3cccc([N+](=O)[O-])c3)cc2n1Cc1...
# ...                                                 ...
# 3083            Cc1c(N[C@@H]2CCC[C@@]2(C)O)ccc(C#N)c1Cl
# 3084            Cc1c(N[C@@H]2CCC[C@@]2(C)O)ccc(C#N)c1Cl
# 3085            Cc1c(N[C@@H]2CCC[C@@]2(C)O)ccc(C#N)c1Cl
# 3086            Cc1c(N[C@@H]2CCC[C@@]2(C)O)ccc(C#N)c1Cl
# 3087            Cc1c(N[C@@H]2CCC[C@@]2(C)O)ccc(C#N)c1Cl
#
#                                                   Core  \
# 0                            O=c1[nH]c2ccc([*:1])cc2s1
# 1                 O=c1[nH]c2ccc(-c3cccc([*:1])c3)cc2s1
# 2                   O=c1[nH]c2ccc([*:1])cc2n1Cc1ccccc1
# 3        O=c1[nH]c2ccc(-c3cccc([*:1])c3)cc2n1Cc1ccccc1
# 4     O=c1[nH]c2ccc(-c3cccc([N+](=O)[O-])c3)cc2n1[*:1]
# ...                                                ...
# 3083                          Cc1c(N[*:1])ccc(C#N)c1Cl
# 3084        Cc1c(N[C@@H]2CCC[C@]2(O)[*:1])ccc(C#N)c1Cl
# 3085        Cc1c(N[C@@H]2CCC[C@]2(C)[*:1])ccc(C#N)c1Cl
# 3086         Cc1c(N[C@@H]2CCC[C@@]2(C)O)ccc([*:1])c1Cl
# 3087        Cc1c(N[C@@H]2CCC[C@@]2(C)O)ccc(C#N)c1[*:1]
#
#                           R_group           Name  pIC50
# 0               Clc1cccc([*:1])c1    CHEMBL94053   6.90
# 1                         Cl[*:1]    CHEMBL94053   6.90
# 2     O=[N+]([O-])c1cccc([*:1])c1   CHEMBL327409   6.15
# 3               O=[N+]([O-])[*:1]   CHEMBL327409   6.15
# 4                c1ccc(C[*:1])cc1   CHEMBL327409   6.15
# ...                           ...            ...    ...
# 3083     C[C@@]1(O)CCC[C@H]1[*:1]  CHEMBL3764185   6.06
# 3084                       C[*:1]  CHEMBL3764185   6.06
# 3085                       O[*:1]  CHEMBL3764185   6.06
# 3086                     N#C[*:1]  CHEMBL3764185   6.06
# 3087                      Cl[*:1]  CHEMBL3764185   6.06
#
# [3088 rows x 5 columns]

# %% [markdown]
# ### View Scaffolds
# Put the scaffolds into a dataframe

# %%
scaffold_df = row_df.Core.value_counts().to_frame().reset_index()
scaffold_df.columns = ["SMILES","Count"]
scaffold_df['mol'] = scaffold_df.SMILES.apply(Chem.MolFromSmiles)
_ = scaffold_df.mol.apply(Compute2DCoords)

# %% [markdown]
# Display the scaffolds

# %%
mols2grid.display(scaffold_df.head(20),subset=["img","Count"],mol_col="mol",
                  use_coords=True,prerender=True)
# Out:
# <iframe class="mols2grid-iframe" width=100% height="514" frameborder="0" srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#       #mols2grid.gridcontainer {
#         display: block;
#         padding-left: 1em;
#         max-width: 820px;
#         width: 820px;
#       }
#       #mols2grid .cell {
#         border: 1px solid #cccccc;
#         text-align: center;
#         vertical-align: top;
#         max-width: 160px;
#         width: 160px;
#         font-family: &#x27;DejaVu&#x27;, sans-serif;
#         font-size: 12pt;
#         padding: 0;
#         margin: 0;
#         float: left;
#       }
#       #mols2grid .cell:hover {
#         background-color: #e7e7e7;
#       }
#       #mols2grid .cell img, #mols2grid .cell svg {
#         max-width: 100%;
#         height: auto;
#         padding: 0;
#       }
#       #mols2grid .data {
#         overflow: hidden;
#         white-space: nowrap;
#         text-overflow: ellipsis;
#         display: block;
#       }
#       #mols2grid .arrow-asc:after {
#         content: &#x27;↑&#x27;;
#         text-align: right;
#         float:right;
#       }
#       #mols2grid .arrow-desc:after {
#         content: &#x27;↓&#x27;;
#         text-align: right;
#         float:right;
#       }
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/list.js/2.3.1/list.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/css/bootstrap.min.css&quot; integrity=&quot;sha384-B0vP5xmATw1+K9KRQjQERJvTumQW0nPEzvF6L/Z6nronJ3oUOFUFpCjEUQouq2+l&quot; crossorigin=&quot;anonymous&quot;&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.5.1.slim.min.js&quot; integrity=&quot;sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@rdkit/rdkit@2021.3.2/Code/MinimalLib/dist/RDKit_minimal.js&quot;&gt;&lt;/script&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mols2grid&quot; class=&quot;gridcontainer&quot;&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;div class=&quot;list&quot;&gt;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Count&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-SMILES&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#       &lt;/div&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;ul class=&quot;pagination pt-3 pl-3 col&quot;&gt;&lt;/ul&gt;
#         &lt;div class=&quot;dropdown float-right col-1 py-3 mr-4&quot;&gt;
#           &lt;button class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; id=&quot;sortDropdown&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;
#             Sort by
#           &lt;/button&gt;
#           &lt;div class=&quot;dropdown-menu&quot; aria-labelledby=&quot;sortDropdownMenu&quot;&gt;
#
#
#             &lt;button class=&quot;dropdown-item sort-btn arrow-asc active&quot; type=&quot;button&quot; data-name=&quot;mols2grid-id&quot;&gt;Index&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-Count&quot;&gt;Count&lt;/button&gt;
#
#
#           &lt;/div&gt;
#         &lt;/div&gt;
#         &lt;div class=&quot;input-group float-right col-4 py-3 mr-3 ml-2&quot;&gt;
#           &lt;input type=&quot;text&quot; id=&quot;searchbar&quot; class=&quot;form-control&quot; placeholder=&quot;Search&quot; aria-label=&quot;Search&quot; aria-describedby=&quot;basic-addon1&quot;&gt;
#           &lt;div class=&quot;input-group-append&quot;&gt;
#             &lt;button id=&quot;searchBtn&quot; class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;🔎&lt;/button&gt;
#             &lt;div class=&quot;dropdown-menu dropdown-menu-right&quot;&gt;
#               &lt;button id=&quot;txtSearch&quot; class=&quot;search-btn dropdown-item active&quot;&gt;Text&lt;/button&gt;
#               &lt;button id=&quot;smartsSearch&quot; class=&quot;search-btn dropdown-item&quot;&gt;SMARTS&lt;/button&gt;
#             &lt;/div&gt;
#           &lt;/div&gt;
#         &lt;/div&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#     &lt;script&gt;
#       // RDKit
#       onRuntimeInitialized: initRDKitModule().then(function(instance) {
#         RDKitModule = instance;
#         console.log(&#x27;RDKit version: &#x27; + RDKitModule.version());
#       });
#       // pages
#       var listObj = new List(&#x27;mols2grid&#x27;,
#         {
#           valueNames: [{data: [&#x27;mols2grid-id&#x27;]}, &#x27;data-Count&#x27;, &#x27;data-SMILES&#x27;, &#x27;data-img&#x27;],
#           item: &#x27;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-Count&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-SMILES&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&#x27;,
#           page: 15,
#           pagination: {
#             name: &quot;pagination&quot;,
#             item: &#x27;&lt;li class=&quot;page-item&quot;&gt;&lt;a class=&quot;page page-link&quot; href=&quot;#&quot; onclick=&quot;event.preventDefault()&quot;&gt;&lt;/a&gt;&lt;/li&gt;&#x27;,
#             innerWindow: 1,
#             outerWindow: 1,
#           },
#         }
#       );
#       listObj.remove(&quot;mols2grid-id&quot;, &quot;0&quot;)
#       listObj.add([{&quot;data-Count&quot;: 31, &quot;data-SMILES&quot;: &quot;CC1=CC(C)(C)Nc2ccc3c(c21)C([*:1])Oc1ccccc1-3&quot;, &quot;data-img&quot;: &quot;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;iso-8859-1&#x27;?&gt;\n&lt;svg version=&#x27;1.1&#x27; baseProfile=&#x27;full&#x27;\n              xmlns=&#x27;http://www.w3.org/2000/svg&#x27;\n                      xmlns:rdkit=&#x27;http://www.rdkit.org/xml&#x27;\n                      xmlns:xlink=&#x27;http://www.w3.org/1999/xlink&#x27;\n                  xml:space=&#x27;preserve&#x27;\nwidth=&#x27;160px&#x27; height=&#x27;120px&#x27; viewBox=&#x27;0 0 160 120&#x27;&gt;\n&lt;!-- END OF HEADER --&gt;\n&lt;rect style=&#x27;opacity:1.0;fill:#FFFFFF;stroke:none&#x27; width=&#x27;160.0&#x27; height=&#x27;120.0&#x27; x=&#x27;0.0&#x27; y=&#x27;0.0&#x27;&gt; &lt;/rect&gt;\n&lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 57.4,90.6 L 50.5,72.2&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 50.5,72.2 L 31.1,69.1&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 49.3,69.1 L 33.2,66.5&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-2 atom-2 atom-3&#x27; d=&#x27;M 31.1,69.1 L 24.1,50.8&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-3 atom-3 atom-4&#x27; d=&#x27;M 24.1,50.8 L 7.3,60.8&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linec

# %% [markdown]
# ### View Matched Molecular Series
# Set **idx** to the index from the scaffold table above to display molecules from that series
# Set **clear_matches** to **False** to highlight the scaffold in the table below

# %%
idx = 4
clear_matches = False
scaffold_smi = scaffold_df.SMILES.values[idx]
scaffold_mol = scaffold_df.mol.values[idx]
scaffold_mol = cleanup_fragment(scaffold_mol)[0]
current_df = row_df.query("Core == @scaffold_smi").sort_values("pIC50",ascending=False).copy()
current_df['mol'] = current_df.SMILES.apply(Chem.MolFromSmiles)
for mol in current_df.mol.values:
    AlignMolToTemplate2D(mol, scaffold_mol)
    if clear_matches:
        mol.__sssAtoms = []
mols2grid.display(current_df,subset=["img","pIC50"],mol_col="mol",use_coords=True,prerender=True)
# Out:
# <iframe class="mols2grid-iframe" width=100% height="514" frameborder="0" srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#       #mols2grid.gridcontainer {
#         display: block;
#         padding-left: 1em;
#         max-width: 820px;
#         width: 820px;
#       }
#       #mols2grid .cell {
#         border: 1px solid #cccccc;
#         text-align: center;
#         vertical-align: top;
#         max-width: 160px;
#         width: 160px;
#         font-family: &#x27;DejaVu&#x27;, sans-serif;
#         font-size: 12pt;
#         padding: 0;
#         margin: 0;
#         float: left;
#       }
#       #mols2grid .cell:hover {
#         background-color: #e7e7e7;
#       }
#       #mols2grid .cell img, #mols2grid .cell svg {
#         max-width: 100%;
#         height: auto;
#         padding: 0;
#       }
#       #mols2grid .data {
#         overflow: hidden;
#         white-space: nowrap;
#         text-overflow: ellipsis;
#         display: block;
#       }
#       #mols2grid .arrow-asc:after {
#         content: &#x27;↑&#x27;;
#         text-align: right;
#         float:right;
#       }
#       #mols2grid .arrow-desc:after {
#         content: &#x27;↓&#x27;;
#         text-align: right;
#         float:right;
#       }
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/list.js/2.3.1/list.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/css/bootstrap.min.css&quot; integrity=&quot;sha384-B0vP5xmATw1+K9KRQjQERJvTumQW0nPEzvF6L/Z6nronJ3oUOFUFpCjEUQouq2+l&quot; crossorigin=&quot;anonymous&quot;&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.5.1.slim.min.js&quot; integrity=&quot;sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@rdkit/rdkit@2021.3.2/Code/MinimalLib/dist/RDKit_minimal.js&quot;&gt;&lt;/script&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mols2grid&quot; class=&quot;gridcontainer&quot;&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;div class=&quot;list&quot;&gt;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-pIC50&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-SMILES&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#       &lt;/div&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;ul class=&quot;pagination pt-3 pl-3 col&quot;&gt;&lt;/ul&gt;
#         &lt;div class=&quot;dropdown float-right col-1 py-3 mr-4&quot;&gt;
#           &lt;button class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; id=&quot;sortDropdown&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;
#             Sort by
#           &lt;/button&gt;
#           &lt;div class=&quot;dropdown-menu&quot; aria-labelledby=&quot;sortDropdownMenu&quot;&gt;
#
#
#             &lt;button class=&quot;dropdown-item sort-btn arrow-asc active&quot; type=&quot;button&quot; data-name=&quot;mols2grid-id&quot;&gt;Index&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-pIC50&quot;&gt;Pic50&lt;/button&gt;
#
#
#           &lt;/div&gt;
#         &lt;/div&gt;
#         &lt;div class=&quot;input-group float-right col-4 py-3 mr-3 ml-2&quot;&gt;
#           &lt;input type=&quot;text&quot; id=&quot;searchbar&quot; class=&quot;form-control&quot; placeholder=&quot;Search&quot; aria-label=&quot;Search&quot; aria-describedby=&quot;basic-addon1&quot;&gt;
#           &lt;div class=&quot;input-group-append&quot;&gt;
#             &lt;button id=&quot;searchBtn&quot; class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;🔎&lt;/button&gt;
#             &lt;div class=&quot;dropdown-menu dropdown-menu-right&quot;&gt;
#               &lt;button id=&quot;txtSearch&quot; class=&quot;search-btn dropdown-item active&quot;&gt;Text&lt;/button&gt;
#               &lt;button id=&quot;smartsSearch&quot; class=&quot;search-btn dropdown-item&quot;&gt;SMARTS&lt;/button&gt;
#             &lt;/div&gt;
#           &lt;/div&gt;
#         &lt;/div&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#     &lt;script&gt;
#       // RDKit
#       onRuntimeInitialized: initRDKitModule().then(function(instance) {
#         RDKitModule = instance;
#         console.log(&#x27;RDKit version: &#x27; + RDKitModule.version());
#       });
#       // pages
#       var listObj = new List(&#x27;mols2grid&#x27;,
#         {
#           valueNames: [{data: [&#x27;mols2grid-id&#x27;]}, &#x27;data-pIC50&#x27;, &#x27;data-SMILES&#x27;, &#x27;data-img&#x27;],
#           item: &#x27;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-pIC50&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-SMILES&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&#x27;,
#           page: 15,
#           pagination: {
#             name: &quot;pagination&quot;,
#             item: &#x27;&lt;li class=&quot;page-item&quot;&gt;&lt;a class=&quot;page page-link&quot; href=&quot;#&quot; onclick=&quot;event.preventDefault()&quot;&gt;&lt;/a&gt;&lt;/li&gt;&#x27;,
#             innerWindow: 1,
#             outerWindow: 1,
#           },
#         }
#       );
#       listObj.remove(&quot;mols2grid-id&quot;, &quot;0&quot;)
#       listObj.add([{&quot;data-pIC50&quot;: 7.66, &quot;mols2grid-id&quot;: 0, &quot;data-SMILES&quot;: &quot;C=C1C[C@H](C)CC(C)(C)[C@@H]1Cc1cc(OC)c(Br)cc1O&quot;, &quot;data-img&quot;: &quot;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;iso-8859-1&#x27;?&gt;\n&lt;svg version=&#x27;1.1&#x27; baseProfile=&#x27;full&#x27;\n              xmlns=&#x27;http://www.w3.org/2000/svg&#x27;\n                      xmlns:rdkit=&#x27;http://www.rdkit.org/xml&#x27;\n                      xmlns:xlink=&#x27;http://www.w3.org/1999/xlink&#x27;\n                  xml:space=&#x27;preserve&#x27;\nwidth=&#x27;160px&#x27; height=&#x27;120px&#x27; viewBox=&#x27;0 0 160 120&#x27;&gt;\n&lt;!-- END OF HEADER --&gt;\n&lt;rect style=&#x27;opacity:1.0;fill:#FFFFFF;stroke:none&#x27; width=&#x27;160.0&#x27; height=&#x27;120.0&#x27; x=&#x27;0.0&#x27; y=&#x27;0.0&#x27;&gt; &lt;/rect&gt;\n&lt;path class=&#x27;bond-10 atom-10 atom-11&#x27; d=&#x27;M 71.1,39.7 L 73.9,40.8 L 74.4,43.7 L 63.1,53.0 L 59.8,49.0 Z&#x27; style=&#x27;fill:#FF7F7F;fill-rule:evenodd;fill-opacity:1;stroke:#FF7F7F;stroke-width:0.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;&#x27; /&gt;\n&lt;path class=&#x27;bond-11 atom-11 atom-12&#x27; d=&#x27;M 76.2,38.9 L 88.5,43.6 L 89.4,49.4 L 74.4,43.7 L 73.9,40.8 Z&#x27; style=&#x27;fill:#FF7F7F;fill-rule:evenodd;fill-opacity:1;stroke:#FF7F7F;stroke-width:0.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;&#x27; /&gt;\n&lt;path class=&#x27;bond-21 atom-11 atom-19&#x27; d=&#x27;M 71.4,24.9 L 74.1,25.9 L 76.2,38.9 L 73.9,40.8 L 71.1,39.7 L 69.1,26.8 Z&#x27; style=&#x27;fill:#FF7F7F;fill-rule:evenodd;fill-opacity:1;stroke:#FF7F7F;stroke-width:0.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;&#x27; /&gt;\n&lt;path class=&#x27;bond-12 atom-12 atom-13&#x27; d=&#x27;M 98.7,35.3 L 101.4,36.3 L 101.9,39.3 L 89.4,49.4 L 88.5,43.6 Z&#x27; style=&#x27;fill:#FF7F7F;fill-rule:evenodd;fill-o
